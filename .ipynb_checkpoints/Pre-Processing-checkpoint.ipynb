# %%
import os
import glob
import mne
import numpy as np
import pandas as pd

# %%
import os
import glob
import mne
import numpy as np
import pandas as pd

# === Paths ===
data_dir = r"C:\Users\bhdib\OneDrive\Desktop\SwanLab_Figures_FP\BDF"
save_dir = r"C:\Users\bhdib\OneDrive\Desktop\SwanLab_Figures_FP\FIF"
os.makedirs(save_dir, exist_ok=True)

# === Define cue triggers ===
short_cue = 2
long_cue = 5
surprise_cue = 8
cue_triggers = {short_cue, long_cue, surprise_cue}
event_id = {
    "short": short_cue,
    "long": long_cue,
    "surprise": surprise_cue
}
REJECTION_THRESHOLD = 300e-6  # 300 µV

# === Loop through BDF files ===
bdf_files = glob.glob(os.path.join(data_dir, "*.bdf"))
print("Found BDF files:", bdf_files)

for file_path in bdf_files:
    print(f"\n--- Processing {file_path} ---")
    subject_id = os.path.basename(file_path).replace(".bdf", "")

    try:
        # Load raw BDF
        raw = mne.io.read_raw_bdf(file_path, preload=True, verbose=False)
        misc_chs = [ch for ch in raw.ch_names if ch.startswith('EXG') or ch.startswith('Erg')]
        raw.set_channel_types({ch: 'misc' for ch in misc_chs})
        raw.set_montage("standard_1020", on_missing='ignore')
        raw.set_eeg_reference('average', projection=True)

        # Find all events
        events = mne.find_events(raw, stim_channel='Status', shortest_event=0.002, verbose=False)
        cue_events = np.array([e for e in events if e[2] in cue_triggers])
        print(f"Total cue events: {len(cue_events)}")

        if len(cue_events) < 2:
            print("❌ Not enough cue events.")
            continue

        # Epoch around cue triggers (now with labels)
        epochs = mne.Epochs(
            raw,
            events=cue_events,
            event_id=event_id,
            tmin=-0.5,
            tmax=1.5,
            baseline=(-0.2, 0),
            preload=True
        )

        # Artifact rejection
        eeg_data = epochs.get_data(picks="eeg")
        bad_mask = np.any(np.abs(eeg_data) > REJECTION_THRESHOLD, axis=(1, 2))
        good_epochs = epochs[~bad_mask]
        good_indices_in_full = np.where(~bad_mask)[0]
        print(f"✔ {len(good_epochs)} clean cue epochs remaining")

        if len(good_indices_in_full) < 2:
            print("❌ Not enough clean epoch pairs to label.")
            continue

        # Sequence labeling
        full_cue_codes = good_epochs.events[:, 2]
        sequence_labels = []

        def get_type(code):
            for name, val in event_id.items():
                if code == val:
                    return name
            return None

        for i in good_indices_in_full:
            if i == 0:
                continue
            prev_code = full_cue_codes[i - 1]
            curr_code = full_cue_codes[i]
            prev_type = get_type(prev_code)
            curr_type = get_type(curr_code)
            if prev_type and curr_type:
                sequence_labels.append(f"{prev_type}_{curr_type}")

        # Drop first epoch so metadata aligns
        good_epochs = good_epochs[1:]
        good_epochs.metadata = pd.DataFrame({'sequence': sequence_labels})

        # Save filtered, labeled epochs
        save_path = os.path.join(save_dir, f"{subject_id}_cue_sequential-epo.fif")
        good_epochs.save(save_path, overwrite=True)
        print(f"✅ Saved: {save_path}")

    except Exception as e:
        print(f"❌ Error processing {file_path}: {e}")
# Out:
# Found BDF files: ['C:\\Users\\bhdib\\OneDrive\\Desktop\\SwanLab_Figures_FP\\BDF\\Foreperiod_Jmlah.bdf', 'C:\\Users\\bhdib\\OneDrive\\Desktop\\SwanLab_Figures_FP\\BDF\\Foreperiod_Sub2.bdf', 'C:\\Users\\bhdib\\OneDrive\\Desktop\\SwanLab_Figures_FP\\BDF\\FP_03.bdf', 'C:\\Users\\bhdib\\OneDrive\\Desktop\\SwanLab_Figures_FP\\BDF\\sub-01-foreperiod-12-3.bdf']
#
# --- Processing C:\Users\bhdib\OneDrive\Desktop\SwanLab_Figures_FP\BDF\Foreperiod_Jmlah.bdf ---
# C:\Users\bhdib\AppData\Local\Temp\ipykernel_15432\3501689723.py:36: RuntimeWarning: The unit for channel(s) EXG1, EXG2, EXG3, EXG4, EXG5, EXG6, EXG7, EXG8, Erg1, Erg2 has changed from V to NA.
#   raw.set_channel_types({ch: 'misc' for ch in misc_chs})
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Total cue events: 756
# Not setting metadata
# ...

# %%
import os
import glob
import mne
import pandas as pd
import numpy as np

# === Paths ===
fif_dir = r"C:\Users\bhdib\OneDrive\Desktop\SwanLab_Figures_FP\FIF"
csv_dir = r"C:\Users\bhdib\OneDrive\Desktop\SwanLab_Figures_FP\Behavioral"
save_dir = os.path.join(fif_dir, "Filtered")
os.makedirs(save_dir, exist_ok=True)

# === RT filter settings (in seconds) ===
min_rt = 0.150
max_rt = 1.000

# === Map behavioral CSV file IDs to .fif EEG IDs ===
subject_map = {
    "617985": "sub-01-foreperiod-12-3",
    "461212": "Foreperiod_Sub2",
    "666227": "FP_03",
    "705027": "Foreperiod_Jmlah"
}

# === Load all behavioral CSVs and organize by EEG subject ID ===
csv_files = glob.glob(os.path.join(csv_dir, "*Foreperiod_task*.csv"))
csv_data = {}

for csv_path in csv_files:
    file_id = os.path.basename(csv_path).split("_")[0]
    eeg_id = subject_map.get(file_id)
    if eeg_id:
        df = pd.read_csv(csv_path)
        df = df[df["RT"].notna()]
        csv_data[eeg_id] = df.reset_index(drop=True)
    else:
        print(f"⚠️ No mapping for {file_id}")

# === Process and filter each .fif file ===
fif_files = glob.glob(os.path.join(fif_dir, "*_cue_sequential-epo.fif"))

for fif_path in fif_files:
    subj_name = os.path.basename(fif_path).replace("_cue_sequential-epo.fif", "")
    print(f"\n🔄 Processing {subj_name}")

    if subj_name not in csv_data:
        print(f"❌ No behavioral data found for {subj_name}")
        continue

    epochs = mne.read_epochs(fif_path, preload=True)
    behav = csv_data[subj_name]

    min_len = min(len(epochs), len(behav))
    epochs = epochs[:min_len]
    behav = behav.iloc[:min_len]

    # Add RT to metadata
    if epochs.metadata is None:
        epochs.metadata = pd.DataFrame(index=np.arange(len(epochs)))
    epochs.metadata["rt"] = behav["RT"].values

    # Filter RTs
    good_mask = (epochs.metadata["rt"] >= min_rt) & (epochs.metadata["rt"] <= max_rt)
    filtered_epochs = epochs[good_mask]

    print(f"✔ {len(filtered_epochs)} / {len(epochs)} epochs retained after RT filtering")

    # Save filtered epochs
    save_path = os.path.join(save_dir, os.path.basename(fif_path))
    filtered_epochs.save(save_path, overwrite=True)
    print(f"✅ Saved: {save_path}")

# %%
import mne
import os
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from mne import combine_evoked

# === Parameters ===
fif_dir = r"C:\Users\bhdib\OneDrive\Desktop\SwanLab_Figures_FP\FIF\Filtered"
subjects = glob.glob(os.path.join(fif_dir, "*_cue_sequential-epo.fif"))

# Dictionary to collect evokeds across subjects
evokeds_all_subjects = {
    "short_short": [], "long_short": [], "surprise_short": [],
    "short_long": [], "long_long": [], "surprise_long": [],
    "short_surprise": [], "long_surprise": [], "surprise_surprise": []
}

# === Subject-level ERP plots ===
for subj_path in subjects:
    subject_name = os.path.basename(subj_path).replace("_cue_sequential-epo.fif", "")
    subject_fig_dir = os.path.join(fif_dir, "SubjectFigures", subject_name)
    os.makedirs(subject_fig_dir, exist_ok=True)

    epochs = mne.read_epochs(subj_path, preload=True)
    sequences = epochs.metadata['sequence'].unique()

    for seq in sequences:
        if seq not in evokeds_all_subjects:
            continue

        evoked = epochs[epochs.metadata['sequence'] == seq].average()
        evokeds_all_subjects[seq].append(evoked)

        fig = evoked.plot(spatial_colors=True, show=False, titles=f"{subject_name} - {seq}")
        fig.savefig(os.path.join(subject_fig_dir, f"{seq}_ERP.png"))
        plt.close(fig)

# === Grand averages and ERP + topomap panels ===
grand_avg_dir = os.path.join(fif_dir, "GrandAverage")
os.makedirs(grand_avg_dir, exist_ok=True)

for seq, evoked_list in evokeds_all_subjects.items():
    if not evoked_list:
        continue

    # Compute grand average
    grand_avg = combine_evoked(evoked_list, weights='equal')

    # Save grand average ERP
    fig1 = grand_avg.plot(spatial_colors=True, show=False, titles=f"Grand Average - {seq}")
    fig1_path = os.path.join(grand_avg_dir, f"GrandAverage_{seq}_ERP.png")
    fig1.savefig(fig1_path)
    plt.close(fig1)

    # Find peak latency for topomap
    peak_ch, peak_time = grand_avg.get_peak(ch_type="eeg", time_as_index=False)

    # Plot topomap (no title argument)
    fig2 = grand_avg.plot_topomap(times=[peak_time], show=False)
    fig2.axes[0].set_title(f"Topomap @ {peak_time*1000:.0f} ms")  # Manually set title
    fig2_path = os.path.join(grand_avg_dir, f"{seq}_Topomap_only.png")
    fig2.savefig(fig2_path)
    plt.close(fig2)

# %%
import matplotlib.pyplot as plt
import os
from mne import combine_evoked, read_epochs

# Path to all FIF files
fif_dir = r"C:\Users\bhdib\OneDrive\Desktop\SwanLab_Figures_FP\FIF\Filtered"
fif_files = glob.glob(os.path.join(fif_dir, "*_cue_sequential-epo.fif"))

# Load and group by sequence
evoked_dict = {}
sequence_labels = [
    "short_short", "short_long", "short_surprise",
    "long_short", "long_long", "long_surprise",
    "surprise_short", "surprise_long", "surprise_surprise"
]
for label in sequence_labels:
    evoked_dict[label] = []

for file in fif_files:
    epochs = read_epochs(file, preload=True)
    for seq in sequence_labels:
        if seq in epochs.metadata['sequence'].unique():
            evoked = epochs[epochs.metadata['sequence'] == seq].average()
            evoked_dict[seq].append(evoked)

# Make grand averages
grand_averages = {
    seq: combine_evoked(evoked_dict[seq], weights='equal')
    for seq in sequence_labels if evoked_dict[seq]
}

# Plot 3x3 ERP grid
fig, axes = plt.subplots(3, 3, figsize=(18, 12))
plt.subplots_adjust(hspace=0.4)

for idx, seq in enumerate(sequence_labels):
    row, col = divmod(idx, 3)
    ax = axes[row, col]
    if seq in grand_averages:
        grand_averages[seq].plot(axes=ax, spatial_colors=True, show=False, titles=seq.replace("_", " →"))
    else:
        ax.set_title(f"No data: {seq}")
        ax.axis("off")

output_path = os.path.join(fif_dir, "GrandAverage", "ERP_3x3_Grid_FIXED.png")
plt.savefig(output_path, dpi=300)
plt.close()

print(f"✅ Fixed 3x3 grid saved to:\n{output_path}")
# Out:
# ✅ Fixed 3x3 grid saved to:
# C:\Users\bhdib\OneDrive\Desktop\SwanLab_Figures_FP\FIF\Filtered\GrandAverage\ERP_3x3_Grid_FIXED.png

# %%
import matplotlib.pyplot as plt
import os
import glob
from mne import combine_evoked, read_epochs

# Path to all FIF files
fif_dir = r"C:\Users\bhdib\OneDrive\Desktop\SwanLab_Figures_FP\FIF\Filtered"
fif_files = glob.glob(os.path.join(fif_dir, "*_cue_sequential-epo.fif"))

# Sequence labels in 3x3 layout order
sequence_labels = [
    "short_short", "short_long", "short_surprise",
    "long_short", "long_long", "long_surprise",
    "surprise_short", "surprise_long", "surprise_surprise"
]

# Load evokeds per sequence
evoked_dict = {seq: [] for seq in sequence_labels}

for file in fif_files:
    epochs = read_epochs(file, preload=True)
    for seq in sequence_labels:
        if seq in epochs.metadata['sequence'].unique():
            evoked = epochs[epochs.metadata['sequence'] == seq].average()
            evoked_dict[seq].append(evoked)

# Create grand averages
grand_averages = {
    seq: combine_evoked(evoked_dict[seq], weights='equal')
    for seq in sequence_labels if evoked_dict[seq]
}

# Create 3x3 topomap figure using saved images from temporary plots
fig, axes = plt.subplots(3, 3, figsize=(12, 9))
plt.subplots_adjust(wspace=0.3, hspace=0.5)

for idx, seq in enumerate(sequence_labels):
    row, col = divmod(idx, 3)
    ax = axes[row, col]
    if seq in grand_averages:
        evoked = grand_averages[seq]
        _, peak_time = evoked.get_peak(ch_type="eeg", time_as_index=False)

        # Generate temporary topomap image
        temp_fig = evoked.plot_topomap(times=[peak_time], show=False)
        temp_fig.axes[0].set_title("")  # remove extra title
        temp_path = os.path.join(fif_dir, "GrandAverage", f"temp_{seq}.png")
        temp_fig.savefig(temp_path, dpi=150)
        plt.close(temp_fig)

        # Load and display as image
        img = plt.imread(temp_path)
        ax.imshow(img)
        ax.axis("off")
        ax.set_title(f"{seq.replace('_', ' →')} @ {peak_time*1000:.0f} ms")
    else:
        ax.set_title(f"No data: {seq}")
        ax.axis("off")

# Save the full grid
final_path = os.path.join(fif_dir, "GrandAverage", "Topomap_3x3_Grid_FIXED.png")
plt.savefig(final_path, dpi=300)
plt.close()

print(f"✅ Fixed topomap grid saved to:\n{final_path}")
# Out:
# ✅ Fixed topomap grid saved to:
# C:\Users\bhdib\OneDrive\Desktop\SwanLab_Figures_FP\FIF\Filtered\GrandAverage\Topomap_3x3_Grid_FIXED.png

# %%
import os
import glob
import mne
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from mne import combine_evoked, read_epochs

# === Paths ===
fif_dir = r"C:\Users\bhdib\OneDrive\Desktop\SwanLab_Figures_FP\FIF\Filtered"
csv_dir = r"C:\Users\bhdib\OneDrive\Desktop\SwanLab_Figures_FP\Behavioral"
channels = ["Cz", "Pz"]

# === Sequence labels for 3x3 grid
sequence_labels = [
    "short_short", "short_long", "short_surprise",
    "long_short", "long_long", "long_surprise",
    "surprise_short", "surprise_long", "surprise_surprise"
]

# === Subject ID map
subject_map = {
    "617985": "sub-01-foreperiod-12-3",
    "461212": "Foreperiod_Sub2",
    "666227": "FP_03",
    "705027": "Foreperiod_Jmlah"
}

# === Load behavioral RTs and group by sequence
sequence_rts = defaultdict(list)

csv_files = glob.glob(os.path.join(csv_dir, "*Foreperiod_task*.csv"))

for csv_file in csv_files:
    file_id = os.path.basename(csv_file).split("_")[0]
    eeg_id = subject_map.get(file_id)
    if not eeg_id:
        continue

    df = pd.read_csv(csv_file)
    df = df[df["RT"].notna()]
    
    fif_path = os.path.join(fif_dir, f"{eeg_id}_cue_sequential-epo.fif")
    if not os.path.exists(fif_path):
        continue

    epochs = read_epochs(fif_path, preload=False)
    df = df.iloc[:len(epochs)]
    sequences = epochs.metadata["sequence"].values[:len(df)]

    for rt, seq in zip(df["RT"].values, sequences):
        sequence_rts[seq].append(rt * 1000)  # RT in ms

# === Compute average RT (click latency) per sequence
mean_rt_per_sequence = {
    seq: np.mean(rts) for seq, rts in sequence_rts.items() if len(rts) > 0
}

# === Load evoked waveforms and compute grand averages
evoked_dict = {seq: [] for seq in sequence_labels}
fif_files = glob.glob(os.path.join(fif_dir, "*_cue_sequential-epo.fif"))

for fif_path in fif_files:
    epochs = read_epochs(fif_path, preload=True)
    for seq in sequence_labels:
        if seq in epochs.metadata['sequence'].unique():
            evoked = epochs[epochs.metadata['sequence'] == seq].average()
            evoked_dict[seq].append(evoked)

grand_averages = {
    seq: combine_evoked(evoked_dict[seq], weights='equal')
    for seq in sequence_labels if evoked_dict[seq]
}

# === Plot ERPs with cue (0 ms) and click markers
fig, axes = plt.subplots(3, 3, figsize=(15, 10), sharex=True, sharey=True)
plt.subplots_adjust(hspace=0.4)

for idx, seq in enumerate(sequence_labels):
    row, col = divmod(idx, 3)
    ax = axes[row, col]

    if seq in grand_averages:
        evoked = grand_averages[seq]
        times = evoked.times * 1000  # ms

        for ch in channels:
            data = evoked.copy().pick(ch).data[0] * 1e6  # µV
            ax.plot(times, data, label=ch)

        ax.axvline(0, color='k', linestyle='--', linewidth=0.75, label='Cue')  # Stimulus onset

        # Add click line at mean RT (behavioral)
        rt = mean_rt_per_sequence.get(seq)
        if rt and 150 < rt < 1500:
            ax.axvline(rt, color='green', linestyle='--', linewidth=1, label='Avg Click')

        ax.set_title(seq.replace("_", " →"))
        ax.set_xlim(-500, 1500)
        ax.set_ylim(-10, 10)
        ax.legend(loc='upper right', fontsize=7)
    else:
        ax.set_title(f"No data: {seq}")
        ax.axis("off")

fig.suptitle("ERPs at Cz and Pz with Cue and Avg Click Markers (Behavioral RT)", fontsize=16)
fig.supxlabel("Time (ms)")
fig.supylabel("Amplitude (µV)")

# === Save figure only (no inline display)
output_path = os.path.join(fif_dir, "Cz_Pz_ERP_3x3_BehavioralAvgClick.png")
plt.savefig(output_path, dpi=300)
plt.close()

print(f"✅ Figure saved to: {output_path}")
# Out:
# ✅ Figure saved to: C:\Users\bhdib\OneDrive\Desktop\SwanLab_Figures_FP\FIF\Filtered\Cz_Pz_ERP_3x3_BehavioralAvgClick.png

# %%
import os
import glob
import mne
import numpy as np
import matplotlib.pyplot as plt

# === Parameters ===
fif_dir = r"C:\Users\bhdib\OneDrive\Desktop\SwanLab_Figures_FP\FIF\Filtered"
save_dir = os.path.join(fif_dir, "TimeFrequency")
os.makedirs(save_dir, exist_ok=True)

frequencies = np.arange(13, 31, 1)  # Beta band: 13–30 Hz
n_cycles = frequencies / 2.  # typical for Morlet: time-frequency tradeoff
baseline = (-0.2, 0)  # baseline period before cue
power_method = 'morlet'

# === Plotting settings ===
channel = 'Cz'  # most likely to show motor preparation or CNV-like activity
sequence_labels = [
    "short_short", "short_long", "short_surprise",
    "long_short", "long_long", "long_surprise",
    "surprise_short", "surprise_long", "surprise_surprise"
]

# === Load and analyze ===
tfrs = {seq: [] for seq in sequence_labels}
fif_files = glob.glob(os.path.join(fif_dir, "*_cue_sequential-epo.fif"))

for fif_path in fif_files:
    epochs = mne.read_epochs(fif_path, preload=True)

    for seq in sequence_labels:
        if seq not in epochs.metadata['sequence'].unique():
            continue
        seq_epochs = epochs[epochs.metadata['sequence'] == seq].copy()
        seq_epochs.pick(channel)

        power = mne.time_frequency.tfr_morlet(
            seq_epochs, freqs=frequencies, n_cycles=n_cycles, use_fft=True,
            return_itc=False, average=True, decim=3, n_jobs=1
        )
        power.apply_baseline(baseline=baseline, mode='percent')
        tfrs[seq].append(power)

# === Grand average per condition
grand_tfrs = {
    seq: mne.grand_average(tfrs[seq]) for seq in sequence_labels if tfrs[seq]
}

# === Plot 3x3 grid of time-frequency maps
fig, axes = plt.subplots(3, 3, figsize=(15, 10), sharex=True, sharey=True)
for idx, seq in enumerate(sequence_labels):
    row, col = divmod(idx, 3)
    ax = axes[row, col]

    if seq in grand_tfrs:
        grand_tfrs[seq].plot([0], baseline=baseline, mode='percent', axes=ax, colorbar=False, show=False)
        ax.set_title(seq.replace("_", " →"))
    else:
        ax.axis('off')
        ax.set_title(f"No data: {seq}")

fig.suptitle(f"Beta-Band (13–30 Hz) Power at {channel} (Baseline-Corrected)", fontsize=16)
output_path = os.path.join(save_dir, f"TFR_Beta_{channel}_3x3.png")
plt.tight_layout()
plt.savefig(output_path, dpi=300)
plt.close()

output_path
# Out:
# 'C:\\Users\\bhdib\\OneDrive\\Desktop\\SwanLab_Figures_FP\\FIF\\Filtered\\TimeFrequency\\TFR_Beta_Cz_3x3.png'

# %%
import os
import glob
import mne
import matplotlib.pyplot as plt

# === Parameters ===
fif_dir = r"C:\Users\bhdib\OneDrive\Desktop\SwanLab_Figures_FP\FIF\Filtered"
save_dir = os.path.join(fif_dir, "GrandAverage")
os.makedirs(save_dir, exist_ok=True)

# Define pairs to compare: current trial is second element
comparison_pairs = [
    ("short_short", "long_short"),
    ("short_long", "long_long"),
    ("short_surprise", "long_surprise")
]

# Electrodes to plot
channels = ["Cz", "Pz"]

# Load data
sequence_labels = [seq for pair in comparison_pairs for seq in pair]
fif_files = glob.glob(os.path.join(fif_dir, "*_cue_sequential-epo.fif"))

# Load and group by sequence
evoked_dict = {label: [] for label in sequence_labels}
for file in fif_files:
    epochs = mne.read_epochs(file, preload=True)
    for seq in sequence_labels:
        if seq in epochs.metadata['sequence'].unique():
            evoked = epochs[epochs.metadata['sequence'] == seq].average()
            evoked_dict[seq].append(evoked)

# Grand average
grand_averages = {
    seq: mne.combine_evoked(evoked_dict[seq], weights='equal')
    for seq in sequence_labels if evoked_dict[seq]
}

# Plotting
fig, axes = plt.subplots(len(comparison_pairs), len(channels), figsize=(10, 9), sharex=True, sharey=True)

for row_idx, (cond1, cond2) in enumerate(comparison_pairs):
    for col_idx, ch in enumerate(channels):
        ax = axes[row_idx, col_idx]
        if cond1 in grand_averages and cond2 in grand_averages:
            ga1 = grand_averages[cond1].copy().pick(ch)
            ga2 = grand_averages[cond2].copy().pick(ch)
            ga1.plot(axes=ax, show=False, time_unit='s', spatial_colors=False, picks=[ch], color='blue')
            ga2.plot(axes=ax, show=False, time_unit='s', spatial_colors=False, picks=[ch], color='orange')
            ax.set_title(f"{cond1.split('_')[1]} vs {cond2.split('_')[1]} at {ch}")
        else:
            ax.set_title(f"{cond1} vs {cond2} at {ch}")
            ax.axis("off")

plt.tight_layout()
output_path = os.path.join(save_dir, "ERP_Comparison_by_Channel.png")
plt.savefig(output_path, dpi=300)
plt.close()

print(f"Saved figure to: {output_path}")
print(output_path)
# Out:
# Saved figure to: C:\Users\bhdib\OneDrive\Desktop\SwanLab_Figures_FP\FIF\Filtered\GrandAverage\ERP_Comparison_by_Channel.png
# C:\Users\bhdib\OneDrive\Desktop\SwanLab_Figures_FP\FIF\Filtered\GrandAverage\ERP_Comparison_by_Channel.png

# %%
import os
import glob
import mne
import matplotlib.pyplot as plt

# === Paths ===
fif_dir = r"C:\Users\bhdib\OneDrive\Desktop\SwanLab_Figures_FP\FIF\Filtered"
fif_files = glob.glob(os.path.join(fif_dir, "*_cue_sequential-epo.fif"))

# === Parameters ===
comparison_pairs = [
    ("short_short", "long_short"),
    ("short_long", "long_long"),
    ("short_surprise", "long_surprise")
]
channels = ["Cz", "Pz"]

# === Load and organize epochs ===
evoked_dict = {label: [] for pair in comparison_pairs for label in pair}
for file in fif_files:
    epochs = mne.read_epochs(file, preload=True)
    for label in evoked_dict:
        if label in epochs.metadata['sequence'].unique():
            evoked = epochs[epochs.metadata['sequence'] == label].average()
            evoked_dict[label].append(evoked)

# === Compute grand averages ===
grand_averages = {
    label: mne.combine_evoked(evoked_dict[label], weights="equal")
    for label in evoked_dict if evoked_dict[label]
}

# === Plotting ===
fig, axes = plt.subplots(len(comparison_pairs), len(channels), figsize=(10, 8), sharex=True, sharey=True)

for row_idx, (cond1, cond2) in enumerate(comparison_pairs):
    for col_idx, ch in enumerate(channels):
        ax = axes[row_idx, col_idx]
        if cond1 in grand_averages and cond2 in grand_averages:
            ev1 = grand_averages[cond1].copy().pick(ch)
            ev2 = grand_averages[cond2].copy().pick(ch)

            ax.plot(ev1.times, ev1.data[0] * 1e6, label=cond1, color='blue')
            ax.plot(ev2.times, ev2.data[0] * 1e6, label=cond2, color='orange')
            ax.axvline(0, color='k', linestyle='--', linewidth=0.5)
            ax.set_title(f"{ch}: {cond1.split('_')[1]} vs {cond2.split('_')[1]}")
            ax.set_ylabel("µV")
            if row_idx == 0:
                ax.legend(loc="upper right")

axes[-1, 0].set_xlabel("Time (s)")
axes[-1, 1].set_xlabel("Time (s)")
plt.suptitle("ERP Comparison by Current Trial Type and Previous Trial", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
